# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.recommender import RecommendationEngine

engine = RecommendationEngine()

engine.train("../data/processed/amazon_cleaned.csv")

engine.recommend("iphone cable")
# Out:
# Dataset loaded successfully!
# Shape: (1337, 12)
# TF-IDF Matrix Created
# (1337, 5000)
# Cosine Similarity Matrix Created
# (1337, 1337)
# Indices Created
# Recommendation Engine Ready!
#                                              Product  \
# 0  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 1  Amazonbasics Nylon Braided Usb-C To Lightning ...
# 2  Belkin Apple Certified Lightning To Type C Cab...
# 3  ESR USB C to Lightning Cable, 10 ft (3 m), MFi...
# 4  AmazonBasics USB C to Lightning Aluminum with ...
# 5  AmazonBasics USB C to Lightning Aluminum with ...
# 6  Wayona Nylon Braided (2 Pack) Lightning Fast U...
# 7  Wayona Type C to Lightning MFI Certified 20W F...
# 8  Wayona Type C to Lightning MFI Certified 20W F...
# 9  SWAPKART Fast Charging Cable and Data Sync USB...
#
#                                             Category   Price  Actual Price  \
# 0  Computers Accessories Accessories Peripherals ...   249.0         999.0
# ...

# %%
engine.recommend("usb c")
# Out:
#                                              Product  \
# 0  SWAPKART Fast Charging Cable and Data Sync USB...
# 1  Syncwire LTG to USB Cable for Fast Charging Co...
# 2  Hi-Mobiler iPhone Charger Lightning Cable,2 Pa...
# 3  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4  Wayona Type C to Lightning MFI Certified 20W F...
# 5  Wayona Type C to Lightning MFI Certified 20W F...
# 6  MYVN LTG to USB for Fast Charging & Data Sync ...
# 7  AmazonBasics USB C to Lightning Aluminum with ...
# 8  AmazonBasics USB C to Lightning Aluminum with ...
# 9  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                             Category  Price  Actual Price  \
# 0  Computers Accessories Accessories Peripherals ...  209.0         499.0
# 1  Computers Accessories Accessories Peripherals ...  399.0        1999.0
# 2  Computers Accessories Accessories Peripherals ...  254.0         799.0
# 3  Computers Accessories Accessories Peripherals ...  399.0        1099.0
# ...

# %%
engine.recommend("wireless mouse")
# Out:
#                                              Product  \
# 0  Dell WM118 Wireless Mouse, 2.4 Ghz with USB Na...
# 1  Logitech M221 Wireless Mouse, Silent Buttons, ...
# 2  Logitech M235 Wireless Mouse, 1000 DPI Optical...
# 3  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# 4  Logitech M331 Silent Plus Wireless Mouse, 2.4G...
# 5  Logitech MK215 Wireless Keyboard and Mouse Com...
# 6  HP Z3700 Wireless Optical Mouse with USB Recei...
# 7  Lenovo 400 Wireless Mouse, 1200DPI Optical Sen...
# 8  Logitech MK240 Nano Wireless USB Keyboard and ...
# 9  Zebronics Zeb-Jaguar Wireless Mouse, 2.4GHz wi...
#
#                                             Category   Price  Actual Price  \
# 0  Computers Accessories Accessories Peripherals ...   569.0        1299.0
# 1  Computers Accessories Accessories Peripherals ...   799.0        1295.0
# 2  Computers Accessories Accessories Peripherals ...   699.0         995.0
# 3  Computers Accessories Accessories Peripherals ...   499.0        1000.0
# ...

# %%
engine.recommend("boat speaker")
# Out:
#                                              Product  \
# 0  Zebronics Zeb Wonderbar 10 USB Powered 2.0 Com...
# 1  Cubetek 3 in 1 LCD Display V5.0 Bluetooth Tran...
# 2  Zebronics ZEB-COUNTY 3W Wireless Bluetooth Por...
# 3  AmazonBasics 10.2 Gbps High-Speed 4K HDMI Cabl...
# 4  EGate i9 Pro-Max 1080p Native Full HD Projecto...
# 5  BlueRigger High Speed HDMI Cable with Ethernet...
# 6  Amazon Basics 10.2 Gbps High-Speed 4K HDMI Cab...
# 7  AmazonBasics - High-Speed Male to Female HDMI ...
# 8  BlueRigger Digital Optical Audio Toslink Cable...
# 9  CableCreation RCA to 3.5mm Male Audio Cable, 3...
#
#                                             Category   Price  Actual Price  \
# 0  Computers Accessories Accessories Peripherals ...   849.0        1499.0
# 1  Electronics HomeTheater,TV Video AVReceivers A...  1990.0        3100.0
# 2   Electronics HomeAudio Speakers BluetoothSpeakers   549.0         999.0
# 3  Electronics HomeTheater,TV Video Accessories C...   609.0        1500.0
# ...

# %%
engine.recommend("gaming keyboard")
# Out:
#                                              Product  \
# 0  Zebronics Wired Keyboard and Mouse Combo with ...
# 1  Zebronics ZEB-KM2100 Multimedia USB Keyboard C...
# 2  Dell KB216 Wired Multimedia USB Keyboard with ...
# 3  Dell USB Wireless Keyboard and Mouse Set- KM33...
# 4  Zebronics Zeb-Companion 107 USB Wireless Keybo...
# 5  Logitech MK270r USB Wireless Keyboard and Mous...
# 6  Logitech MK215 Wireless Keyboard and Mouse Com...
# 7  Portronics Key2 Combo Multimedia USB Wireless ...
# 8  Quantum QHM-7406 Full-Sized Keyboard with (₹) ...
# 9  Logitech MK240 Nano Wireless USB Keyboard and ...
#
#                                             Category   Price  Actual Price  \
# 0  Computers Accessories Accessories Peripherals ...   448.0         699.0
# 1  Computers Accessories Accessories Peripherals ...   329.0         399.0
# 2  Computers Accessories Accessories Peripherals ...   549.0        1799.0
# 3  Computers Accessories Accessories Peripherals ...  1399.0        2498.0
# ...

# %%
engine.recommend(
    "wireless mouse",
    min_rating=4.3
)
# Out:
#                                              Product  \
# 0  Dell WM118 Wireless Mouse, 2.4 Ghz with USB Na...
# 1  Logitech M221 Wireless Mouse, Silent Buttons, ...
# 2  Logitech M235 Wireless Mouse, 1000 DPI Optical...
# 3  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# 4  Logitech M331 Silent Plus Wireless Mouse, 2.4G...
# 5  Lenovo 400 Wireless Mouse, 1200DPI Optical Sen...
# 6  Logitech MK240 Nano Wireless USB Keyboard and ...
#
#                                             Category   Price  Actual Price  \
# 0  Computers Accessories Accessories Peripherals ...   569.0        1299.0
# 1  Computers Accessories Accessories Peripherals ...   799.0        1295.0
# 2  Computers Accessories Accessories Peripherals ...   699.0         995.0
# 3  Computers Accessories Accessories Peripherals ...   499.0        1000.0
# 4  Computers Accessories Accessories Peripherals ...  1295.0        1645.0
# 5  Computers Accessories Accessories Peripherals ...   629.0        1390.0
# ...
